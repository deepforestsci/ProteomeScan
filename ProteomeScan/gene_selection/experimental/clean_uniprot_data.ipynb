# %%
import pandas as pd

# %%
df = pd.read_csv("/home/ary2260/Work/DeepForest/customer_small/vevo/human_prote/uniprotkb_proteome_UP000005640_AND_revi_2024_09_30.tsv", sep="\t")

# %%
df = df.dropna()

# %%
df = df.drop_duplicates(subset='Gene Names (primary)', keep='first')

# %%
df = df.reset_index(drop=True)

# %%
df['Gene Names (primary)']

# %%
df.to_csv("18337_genes_reviewed_human_prot.csv", index=False)
